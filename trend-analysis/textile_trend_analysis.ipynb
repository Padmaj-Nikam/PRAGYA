# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/0.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/100.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/1000.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10000.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10001.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10002.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10003.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10004.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10005.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10006.jpg
# /home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images/10007.jpg
# ...

# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
import numpy as np
from numpy.linalg import norm
import os
from tqdm import tqdm
import pickle
# Out:
# 2023-12-12 22:29:10.959373: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-12 22:29:16.127224: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-12 22:29:16.127288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-12 22:29:16.617184: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-12 22:29:17.378761: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
model = ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))

# %%
model.trainable = False

# %%
model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d (Glob  (None, 2048)              0
#  alMaxPooling2D)
#
# ...
# Total params: 23587712 (89.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# None

# %%
def extract_features(img_path,model):
    img = image.load_img(img_path,target_size=(224,224))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result / norm(result)

    return normalized_result

# %%
filenames = []

for file in os.listdir('/home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images'):
    filenames.append(os.path.join('/home/paddie/Documents/pragya1/PRAGYA/datasets/datasets/Images/Images',file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(extract_features(file,model))
# Out:
# ...
# 100%|██████████| 110/110 [00:43<00:00,  2.55it/s]

# %%
pickle.dump(feature_list,open('embeddings.pkl','wb'))
pickle.dump(filenames,open('filenames.pkl','wb'))
